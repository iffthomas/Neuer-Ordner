# %%
from datetime import datetime, timedelta
from mplsoccer import VerticalPitch, Pitch
from matplotlib import animation
import matplotlib.pyplot as plt
from pathlib import Path
import imageio.v2 as iio
from tqdm import tqdm
import pandas as pd
import matplotlib
import zipfile
import shutil
import time
import json
import enum
from pathlib import Path
from pathlib import Path
import zipfile
# set pandas option to show columns of a dataframe
pd.set_option('display.max_columns', None)
import os
import sys
# Add the parent directory to sys.path to access the 'models' package
sys.path.append('..')

from models.setup_skillcorner import get_skillcorner_database, get_skillcorner_dataframes

# %%
def wyscout_json_to_df(file_name):
    # Create a directory to extract files to (same as zip file name without extension)
    extract_dir = file_name.split(".")[0]
    os.makedirs(extract_dir, exist_ok=True)  # Create the directory if it doesn't exist

    # Unzip the file
    with zipfile.ZipFile(file_name, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    
    # Construct the full path to the json file
    json_name = os.path.join(extract_dir, os.path.basename(extract_dir) + ".json")

    # Read the json file
    with open(json_name, encoding='utf8') as f:
        js = json.load(f)
        df = pd.json_normalize(js['events'])
    return df

# %%
#get path of current directory in jupyter
current_directory = Path.cwd()
current_directory = current_directory.parents[0]


data_dir = os.path.join(current_directory,'data','england_games')
if not os.path.exists(data_dir):
    os.makedirs(data_dir)
data_dir = Path(data_dir)


#path for matchid's
data_path= os.path.join(current_directory,'data')
wyscout_path = os.path.join(data_path,'wyscout')
input_dir = os.path.join(data_path,'skillcorner')
match_id_path = os.path.join(data_path,'matchids.csv')


#open matchid file
match_id = pd.read_csv(match_id_path)

#select matches where "home" == England or away == England
england_match = match_id[(match_id['home'] == 'England') | (match_id['away'] == 'England')]

# %%
england_match
# Out:
#      wyscout  skillcorner        date             home result             away
# 1    5414104          NaN  2023-03-23            Italy    1-2          England
# 25   5414127     726848.0  2023-03-26          England    2-0          Ukraine
# 49   5414149          NaN  2023-06-16            Malta    0-4          England
# 74   5414173          NaN  2023-06-19          England    7-0  North Macedonia
# 114  5414212          NaN  2023-09-09          Ukraine    1-1          England
# 183  5414280    1381470.0  2023-10-17          England    3-1            Italy
# 204  5414298    1381488.0  2023-11-17          England    2-0            Malta
# 226  5414319    1381509.0  2023-11-20  North Macedonia    1-1          England

# %%
match_id = 726848
wyscout_id = england_match[england_match["skillcorner"] == match_id]["wyscout"].values[0]

#get all_dfs

save_dir = get_skillcorner_database(input_dir, match_id, data_dir)
(metadata_df, 
 play_direction_df, 
 phase_df, 
 lineup_df, 
 tracking_df, 
 visible_area_df, 
 physical_df, 
 passes_df, 
 on_ball_pressures_df, 
 off_ball_runs_df) = get_skillcorner_dataframes(save_dir, match_id)
# Out:
# Metadata 726848 added ...
# PlayDirection 726848 added ...
# Tracking 726848 added ...
# Visible Area 726848 added ...
# Phase 726848 added ...
# Lineup 726848 added ...
# physical 726848 added ...
# passes 726848 added ...
# on_ball_pressures 726848 added ...
# off_ball_runs 726848 added ...
# Execution Time is 00:09

# %%
ball_id = tracking_df[tracking_df["z"]==tracking_df.z.max()]
ball_id["object_id"].values[0]

ball_during_game = tracking_df[tracking_df["object_id"]==ball_id["object_id"].values[0]]
ball_during_game


drop_columns = ["match_id", "half", "frame_id", "object_id", "extrapolated"]
ball_during_game = ball_during_game.drop(columns=drop_columns)
ball_during_game= ball_during_game.drop(columns = ["z"])

# %%
wyscout_event = wyscout_json_to_df(file_name = os.path.join(wyscout_path, f"{wyscout_id}.zip"))
wyscout_event = wyscout_event[wyscout_event["type.primary"] == "pass"]

# %%
wyscout_event
# Out:
#               id  matchId matchPeriod  minute  second matchTimestamp  \
# 0     1716939794  5414127          1H       0       4   00:00:04.109
# 1     1716939795  5414127          1H       0       9   00:00:09.124
# 6     1716939243  5414127          1H       0      35   00:00:35.432
# 11    1716939247  5414127          1H       2      16   00:02:16.603
# 12    1716939248  5414127          1H       2      18   00:02:18.583
# ...          ...      ...         ...     ...     ...            ...
# 1664  1716940445  5414127          2H      92      25   01:32:25.909
# 1665  1716940447  5414127          2H      92      28   01:32:28.667
# 1672  1716939785  5414127          2H      92      52   01:32:52.289
# 1673  1716939786  5414127          2H      92      55   01:32:55.931
# 1674  1716939787  5414127          2H      92      57   01:32:57.495
#
#      videoTimestamp  relatedEventId  shot  groundDuel  aerialDuel  infraction  \
# 0          5.109585    1.716940e+09   NaN         NaN         NaN         NaN
# 1           10.1243    1.716939e+09   NaN         NaN         NaN         NaN
# 6          36.43259    1.716938e+09   NaN         NaN         NaN         NaN
# 11       137.603103    1.716939e+09   NaN         NaN         NaN         NaN
# 12       139.583219    1.716940e+09   NaN         NaN         NaN         NaN
# ...             ...             ...   ...         ...         ...         ...
# 1664    5738.909474    1.716940e+09   NaN         NaN         NaN         NaN
# 1665    5741.667244    1.716939e+09   NaN         NaN         NaN         NaN
# 1672    5765.289094    1.716940e+09   NaN         NaN         NaN         NaN
# 1673    5768.931607    1.716940e+09   NaN         NaN         NaN         NaN
# 1674    5770.495763    1.716940e+09   NaN         NaN         NaN         NaN
#
#       carry type.primary                                     type.secondary  \
# 0       NaN         pass                  [back_pass, short_or_medium_pass]
# 1       NaN         pass  [forward_pass, long_pass, pass_to_final_third,...
# 6       NaN         pass        [forward_pass, long_pass, progressive_pass]
# 11      NaN         pass               [lateral_pass, short_or_medium_pass]
# 12      NaN         pass  [forward_pass, long_pass, loss, pass_to_final_...
# ...     ...          ...                                                ...
# 1664    NaN         pass                          [forward_pass, long_pass]
# 1665    NaN         pass  [head_pass, linkup_play, progressive_pass, sho...
# 1672    NaN         pass                  [back_pass, short_or_medium_pass]
# 1673    NaN         pass  [forward_pass, long_pass, pass_to_final_third,...
# 1674    NaN         pass                       [loss, short_or_medium_pass]
#
#       location.x  location.y  team.id team.name team.formation  \
# 0             51          50     2413   England          4-3-3
# 1             41          44     2413   England          4-3-3
# 6              8          56    14622   Ukraine        4-2-3-1
# 11            34          30    14622   Ukraine        4-2-3-1
# 12            43           3    14622   Ukraine        4-2-3-1
# ...          ...         ...      ...       ...            ...
# 1664          10          10    14622   Ukraine        4-2-3-1
# 1665          30           9    14622   Ukraine        4-2-3-1
# 1672          75          91     2413   England          4-3-3
# 1673          63          87     2413   England          4-3-3
# 1674          79          90     2413   England          4-3-3
#
#       opponentTeam.id opponentTeam.name opponentTeam.formation  player.id  \
# 0               14622           Ukraine                4-2-3-1     520291
# 1               14622           Ukraine                4-2-3-1       9380
# 6                2413           England                  4-3-3     532782
# 11               2413           England                  4-3-3     283279
# 12               2413           England                  4-3-3     406073
# ...               ...               ...                    ...        ...
# 1664             2413           England                  4-3-3     283279
# 1665             2413           England                  4-3-3     105378
# 1672            14622           Ukraine                4-2-3-1       7964
# 1673            14622           Ukraine                4-2-3-1       8277
# 1674            14622           Ukraine                4-2-3-1       7964
#
#          player.name player.position pass.accurate  pass.angle pass.height  \
# 0            B. Saka             RWF          True      -160.0        None
# 1          J. Stones             RCB          True       -25.0        high
# 6          A. Trubin              GK          True        -7.0        high
# 11      M. Matvienko             LCB          True       -63.0        None
# 12      V. Mykolenko              LB         False         8.0        high
# ...              ...             ...           ...         ...         ...
# 1664    M. Matvienko             LCB          True        -3.0        high
# 1665  Y. Konoplyanka            LAMF         False        63.0        high
# 1672    J. Henderson           RCMF3          True      -167.0        None
# 1673       K. Walker              RB          True         7.0        high
# 1674    J. Henderson           RCMF3         False       -54.0        None
#
#       pass.length  pass.recipient.id pass.recipient.name  \
# 0            11.0             9380.0           J. Stones
# 1            46.0             8717.0             H. Kane
# 6            31.0           138548.0      R. Malinovskyi
# 11           21.0           406073.0        V. Mykolenko
# 12           35.0             9380.0           J. Stones
# ...           ...                ...                 ...
# 1664         21.0           105378.0      Y. Konoplyanka
# 1665          9.0             8277.0           K. Walker
# 1672         13.0             8277.0           K. Walker
# 1673         17.0             7964.0        J. Henderson
# 1674          9.0           138478.0            E. Sobol
#
#      pass.recipient.position  pass.endLocation.x  pass.endLocation.y  \
# 0                        RCB                41.0                44.0
# 1                         CF                81.0                15.0
# 6                       RAMF                37.0                50.0
# 11                        LB                43.0                 3.0
# 12                       RCB                76.0                11.0
# ...                      ...                 ...                 ...
# 1664                    LAMF                30.0                 9.0
# 1665                      RB                34.0                21.0
# 1672                      RB                63.0                87.0
# 1673                   RCMF3                79.0                90.0
# 1674                      LB                84.0                80.0
#
#       possession.id possession.duration  \
# 0      1.716940e+09            9.854864
# 1      1.716940e+09            9.854864
# 6      1.716939e+09           9.2871205
# 11     1.716939e+09            7.074654
# 12     1.716939e+09            7.074654
# ...             ...                 ...
# 1664   1.716939e+09           10.353608
# 1665   1.716939e+09           10.353608
# 1672   1.716939e+09           7.9360865
# 1673   1.716939e+09           7.9360865
# 1674   1.716939e+09           7.9360865
#
#                            possession.types  possession.eventsNumber  \
# 0                                        []                      5.0
# 1                                        []                      5.0
# 6             [set_piece_attack, free_kick]                      5.0
# 11            [set_piece_attack, free_kick]                      3.0
# 12            [set_piece_attack, free_kick]                      3.0
# ...                                     ...                      ...
# 1664          [set_piece_attack, free_kick]                      7.0
# 1665          [set_piece_attack, free_kick]                      7.0
# 1672  [set_piece_attack, attack, free_kick]                      4.0
# 1673  [set_piece_attack, attack, free_kick]                      4.0
# 1674  [set_piece_attack, attack, free_kick]                      4.0
#
#       possession.eventIndex  possession.startLocation.x  \
# 0                       0.0                        51.0
# 1                       1.0                        51.0
# 6                       1.0                         0.0
# 11                      1.0                        39.0
# 12                      2.0                        39.0
# ...                     ...                         ...
# 1664                    3.0                         7.0
# 1665                    4.0                         7.0
# 1672                    1.0                        67.0
# 1673                    2.0                        67.0
# 1674                    3.0                        67.0
#
#       possession.startLocation.y  possession.endLocation.x  \
# 0                           50.0                     100.0
# 1                           50.0                     100.0
# 6                           45.0                      39.0
# 11                          52.0                      76.0
# 12                          52.0                      76.0
# ...                          ...                       ...
# 1664                        11.0                      34.0
# 1665                        11.0                      34.0
# 1672                        72.0                      84.0
# 1673                        72.0                      84.0
# 1674                        72.0                      84.0
#
#       possession.endLocation.y  possession.team.id possession.team.name  \
# 0                         14.0              2413.0              England
# 1                         14.0              2413.0              England
# 6                         52.0             14622.0              Ukraine
# 11                        11.0             14622.0              Ukraine
# 12                        11.0             14622.0              Ukraine
# ...                        ...                 ...                  ...
# 1664                      21.0             14622.0              Ukraine
# 1665                      21.0             14622.0              Ukraine
# 1672                      80.0              2413.0              England
# 1673                      80.0              2413.0              England
# 1674                      80.0              2413.0              England
#
#      possession.team.formation  possession.attack  pass  \
# 0                        4-3-3                NaN   NaN
# 1                        4-3-3                NaN   NaN
# 6                      4-2-3-1                NaN   NaN
# 11                     4-2-3-1                NaN   NaN
# 12                     4-2-3-1                NaN   NaN
# ...                        ...                ...   ...
# 1664                   4-2-3-1                NaN   NaN
# 1665                   4-2-3-1                NaN   NaN
# 1672                     4-3-3                NaN   NaN
# 1673                     4-3-3                NaN   NaN
# 1674                     4-3-3                NaN   NaN
#
#       aerialDuel.opponent.id aerialDuel.opponent.name  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 6                        NaN                      NaN
# 11                       NaN                      NaN
# 12                       NaN                      NaN
# ...                      ...                      ...
# 1664                     NaN                      NaN
# 1665                     NaN                      NaN
# 1672                     NaN                      NaN
# 1673                     NaN                      NaN
# 1674                     NaN                      NaN
#
#      aerialDuel.opponent.position  aerialDuel.opponent.height  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 6                             NaN                         NaN
# 11                            NaN                         NaN
# 12                            NaN                         NaN
# ...                           ...                         ...
# 1664                          NaN                         NaN
# 1665                          NaN                         NaN
# 1672                          NaN                         NaN
# 1673                          NaN                         NaN
# 1674                          NaN                         NaN
#
#      aerialDuel.firstTouch  aerialDuel.height  aerialDuel.relatedDuelId  \
# 0                      NaN                NaN                       NaN
# 1                      NaN                NaN                       NaN
# 6                      NaN                NaN                       NaN
# 11                     NaN                NaN                       NaN
# 12                     NaN                NaN                       NaN
# ...                    ...                ...                       ...
# 1664                   NaN                NaN                       NaN
# 1665                   NaN                NaN                       NaN
# 1672                   NaN                NaN                       NaN
# 1673                   NaN                NaN                       NaN
# 1674                   NaN                NaN                       NaN
#
#      infraction.yellowCard infraction.redCard infraction.type  \
# 0                      NaN                NaN             NaN
# 1                      NaN                NaN             NaN
# 6                      NaN                NaN             NaN
# 11                     NaN                NaN             NaN
# 12                     NaN                NaN             NaN
# ...                    ...                ...             ...
# 1664                   NaN                NaN             NaN
# 1665                   NaN                NaN             NaN
# 1672                   NaN                NaN             NaN
# 1673                   NaN                NaN             NaN
# 1674                   NaN                NaN             NaN
#
#       infraction.opponent.id infraction.opponent.name  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 6                        NaN                      NaN
# 11                       NaN                      NaN
# 12                       NaN                      NaN
# ...                      ...                      ...
# 1664                     NaN                      NaN
# 1665                     NaN                      NaN
# 1672                     NaN                      NaN
# 1673                     NaN                      NaN
# 1674                     NaN                      NaN
#
#      infraction.opponent.position  carry.progression  carry.endLocation.x  \
# 0                             NaN                NaN                  NaN
# 1                             NaN                NaN                  NaN
# 6                             NaN                NaN                  NaN
# 11                            NaN                NaN                  NaN
# 12                            NaN                NaN                  NaN
# ...                           ...                ...                  ...
# 1664                          NaN                NaN                  NaN
# 1665                          NaN                NaN                  NaN
# 1672                          NaN                NaN                  NaN
# 1673                          NaN                NaN                  NaN
# 1674                          NaN                NaN                  NaN
#
#       carry.endLocation.y  groundDuel.opponent.id groundDuel.opponent.name  \
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 6                     NaN                     NaN                      NaN
# 11                    NaN                     NaN                      NaN
# 12                    NaN                     NaN                      NaN
# ...                   ...                     ...                      ...
# 1664                  NaN                     NaN                      NaN
# 1665                  NaN                     NaN                      NaN
# 1672                  NaN                     NaN                      NaN
# 1673                  NaN                     NaN                      NaN
# 1674                  NaN                     NaN                      NaN
#
#      groundDuel.opponent.position groundDuel.duelType  \
# 0                             NaN                 NaN
# 1                             NaN                 NaN
# 6                             NaN                 NaN
# 11                            NaN                 NaN
# 12                            NaN                 NaN
# ...                           ...                 ...
# 1664                          NaN                 NaN
# 1665                          NaN                 NaN
# 1672                          NaN                 NaN
# 1673                          NaN                 NaN
# 1674                          NaN                 NaN
#
#      groundDuel.keptPossession groundDuel.progressedWithBall  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 6                          NaN                           NaN
# 11                         NaN                           NaN
# 12                         NaN                           NaN
# ...                        ...                           ...
# 1664                       NaN                           NaN
# 1665                       NaN                           NaN
# 1672                       NaN                           NaN
# 1673                       NaN                           NaN
# 1674                       NaN                           NaN
#
#      groundDuel.stoppedProgress groundDuel.recoveredPossession  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 6                           NaN                            NaN
# 11                          NaN                            NaN
# 12                          NaN                            NaN
# ...                         ...                            ...
# 1664                        NaN                            NaN
# 1665                        NaN                            NaN
# 1672                        NaN                            NaN
# 1673                        NaN                            NaN
# 1674                        NaN                            NaN
#
#      groundDuel.takeOn groundDuel.side  groundDuel.relatedDuelId  \
# 0                  NaN             NaN                       NaN
# 1                  NaN             NaN                       NaN
# 6                  NaN             NaN                       NaN
# 11                 NaN             NaN                       NaN
# 12                 NaN             NaN                       NaN
# ...                ...             ...                       ...
# 1664               NaN             NaN                       NaN
# 1665               NaN             NaN                       NaN
# 1672               NaN             NaN                       NaN
# 1673               NaN             NaN                       NaN
# 1674               NaN             NaN                       NaN
#
#      possession.attack.withShot possession.attack.withShotOnGoal  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 6                           NaN                              NaN
# 11                          NaN                              NaN
# 12                          NaN                              NaN
# ...                         ...                              ...
# 1664                        NaN                              NaN
# 1665                        NaN                              NaN
# 1672                      False                            False
# 1673                      False                            False
# 1674                      False                            False
#
#      possession.attack.withGoal possession.attack.flank  possession.attack.xg  \
# 0                           NaN                     NaN                   NaN
# 1                           NaN                     NaN                   NaN
# 6                           NaN                     NaN                   NaN
# 11                          NaN                     NaN                   NaN
# 12                          NaN                     NaN                   NaN
# ...                         ...                     ...                   ...
# 1664                        NaN                     NaN                   NaN
# 1665                        NaN                     NaN                   NaN
# 1672                      False                   right                   0.0
# 1673                      False                   right                   0.0
# 1674                      False                   right                   0.0
#
#      shot.bodyPart shot.isGoal shot.onTarget shot.goalZone  shot.xg  \
# 0              NaN         NaN           NaN           NaN      NaN
# 1              NaN         NaN           NaN           NaN      NaN
# 6              NaN         NaN           NaN           NaN      NaN
# 11             NaN         NaN           NaN           NaN      NaN
# 12             NaN         NaN           NaN           NaN      NaN
# ...            ...         ...           ...           ...      ...
# 1664           NaN         NaN           NaN           NaN      NaN
# 1665           NaN         NaN           NaN           NaN      NaN
# 1672           NaN         NaN           NaN           NaN      NaN
# 1673           NaN         NaN           NaN           NaN      NaN
# 1674           NaN         NaN           NaN           NaN      NaN
#
#       shot.postShotXg  shot.goalkeeperActionId  shot.goalkeeper  possession  \
# 0                 NaN                      NaN              NaN         NaN
# 1                 NaN                      NaN              NaN         NaN
# 6                 NaN                      NaN              NaN         NaN
# 11                NaN                      NaN              NaN         NaN
# 12                NaN                      NaN              NaN         NaN
# ...               ...                      ...              ...         ...
# 1664              NaN                      NaN              NaN         NaN
# 1665              NaN                      NaN              NaN         NaN
# 1672              NaN                      NaN              NaN         NaN
# 1673              NaN                      NaN              NaN         NaN
# 1674              NaN                      NaN              NaN         NaN
#
#       shot.goalkeeper.id shot.goalkeeper.name
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 6                    NaN                  NaN
# 11                   NaN                  NaN
# 12                   NaN                  NaN
# ...                  ...                  ...
# 1664                 NaN                  NaN
# 1665                 NaN                  NaN
# 1672                 NaN                  NaN
# 1673                 NaN                  NaN
# 1674                 NaN                  NaN
#
# [1010 rows x 92 columns]

# %%
#select_all columns that have pass in it also include these location.x	location.y
passes_df = wyscout_event.filter(regex='pass|location|possession.types|team.name|matchPeriod')
#change matchperiod 1h 2h to 1 or 2
passes_df["matchPeriod"] = passes_df["matchPeriod"].apply(lambda x: 1 if x == "1H" else 2)
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_8160\229427897.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   passes_df["matchPeriod"] = passes_df["matchPeriod"].apply(lambda x: 1 if x == "1H" else 2)

# %%
pitch = Pitch(pitch_type='wyscout', goal_type='box', pitch_color='#53ac5c',
                      line_color='white', linewidth=3, corner_arcs=True)
fig, ax = pitch.draw()

pitch.arrows(passes_df['location.y'], passes_df['location.x'],
             passes_df['pass.endLocation.y'], passes_df['pass.endLocation.x'],
             width=2, headwidth=2, color='blue', ax=ax, label='completed passes')

# %%
passes_df["possession.types"].value_counts()


#filter out if it is a set_piece_attack or free_kick are in the list in possession.types
# Out:
# possession.types
# [attack, throw_in]                                        157
# [attack]                                                  121
# []                                                        118
# [set_piece_attack, attack, free_kick]                     105
# [set_piece_attack, free_kick]                             100
# [attack, transition_medium]                                81
# [transition_medium]                                        79
# [transition_low]                                           68
# [attack, transition_low]                                   51
# [throw_in]                                                 38
# [attack, transition_high]                                  24
# [corner, set_piece_attack, attack]                         21
# [counterattack, attack]                                    21
# [set_piece_attack, attack, free_kick, free_kick_cross]     19
# [counterattack, attack, transition_medium]                  4
# [counterattack, transition_low]                             3
# Name: count, dtype: int64

# %%
# Filter out rows where 'possession.types' contains 'set_piece' or 'free_kick'
filtered_df = passes_df[~passes_df["possession.types"].apply(lambda x: 'set_piece' in x or 'free_kick' in x)]

# %%
filtered_df
# Out:
#       matchPeriod  location.x  location.y team.name pass.accurate  pass.angle  \
# 0               1          51          50   England          True      -160.0
# 1               1          41          44   England          True       -25.0
# 13              1          24          89   England          True      -135.0
# 14              1           6          62   England          True       -73.0
# 15              1          15          14   England          True       -29.0
# ...           ...         ...         ...       ...           ...         ...
# 1625            2          95          90   England         False      -149.0
# 1642            2          45          55   England          True       180.0
# 1645            2          38          65   England         False       -45.0
# 1648            2          76          41   England          True       -31.0
# 1655            2          95          86   England          True       104.0
#
#      pass.height  pass.length  pass.recipient.id pass.recipient.name  \
# 0           None         11.0             9380.0           J. Stones
# 1           high         46.0             8717.0             H. Kane
# 13          None         26.0            10131.0         J. Pickford
# 14          None         34.0             8653.0          H. Maguire
# 15          None         10.0           350976.0         B. Chilwell
# ...          ...          ...                ...                 ...
# 1625     blocked        117.0                0.0                None
# 1642        None          1.0                0.0                None
# 1645        None         10.0           544823.0          H. Sudakov
# 1648        None         12.0            11051.0         J. Grealish
# 1655        None          8.0             7964.0        J. Henderson
#
#      pass.recipient.position  pass.endLocation.x  pass.endLocation.y  \
# 0                        RCB                41.0                44.0
# 1                         CF                81.0                15.0
# 13                        GK                 6.0                62.0
# 14                       LCB                15.0                14.0
# 15                        LB                24.0                 8.0
# ...                      ...                 ...                 ...
# 1625                    None                 0.0                 0.0
# 1642                    None                44.0                55.0
# 1645                    LDMF                45.0                55.0
# 1648                     LWF                86.0                33.0
# 1655                   RCMF3                93.0                97.0
#
#                         possession.types possession.team.name  pass
# 0                                     []              England   NaN
# 1                                     []              England   NaN
# 13                      [transition_low]              England   NaN
# 14                      [transition_low]              England   NaN
# 15                      [transition_low]              England   NaN
# ...                                  ...                  ...   ...
# 1625            [attack, transition_low]              England   NaN
# 1642             [counterattack, attack]              England   NaN
# 1645             [counterattack, attack]              England   NaN
# 1648             [counterattack, attack]              England   NaN
# 1655  [corner, set_piece_attack, attack]              England   NaN
#
# [786 rows x 16 columns]

# %%
for i in range(0,2):
    pitch = Pitch(pitch_type='wyscout', goal_type='box', pitch_color='#53ac5c',
                        line_color='white', linewidth=3, corner_arcs=True)
    fig, ax = pitch.draw()

    for team in filtered_df["team.name"].unique():
        team_df = filtered_df[(filtered_df["team.name"] == team) & (filtered_df["matchPeriod"] == i+1)]

        if team == "England":
            color = "red"
        else:
            color = "yellow"
        pitch.arrows(team_df['location.y'], team_df['location.x'],
                team_df['pass.endLocation.y'], team_df['pass.endLocation.x'],
                width=2, headwidth=2, color=color, ax=ax, label='completed passes')
    plt.show()

# %%
for i in range(0,2):
    print(i+1)
    filtered_df_temp = filtered_df[filtered_df["matchPeriod"]==i+1]
    
    teams = wyscout_event["team.name"].unique()
    pitch = Pitch(pitch_type='wyscout', goal_type='box', pitch_color='#53ac5c',
                        line_color='white', linewidth=3, corner_arcs=True)
    fig, ax = pitch.draw(figsize=(16, 11))


    for team in teams:
        #select a color for the team
        if team == "England":
            color = "red"
        else:
            color = "yellow"
        failed_passes = filtered_df_temp[filtered_df_temp["pass.accurate"] == False]
        failed_passes = failed_passes[failed_passes["pass.recipient.position"]!="GK"] #ignore the passes of the goal keeper
        failed_passes = failed_passes[failed_passes["team.name"]==team]


        #dropnas
        failed_passes = failed_passes.dropna(subset=["location.x", "location.y", "pass.endLocation.x", "pass.endLocation.y","pass.recipient.position" ])

        pitch.arrows(failed_passes['location.y'], failed_passes['location.x'],
                    failed_passes['pass.endLocation.y'], failed_passes['pass.endLocation.x'],
                    width=2, headwidth=2, color=color, ax=ax, label='completed passes')
    plt.show()
# Out:
# 1
# 2

# %%
df
